# %%
# !pip install openai==1.13.3
# Out:
# Requirement already satisfied: openai==1.13.3 in /usr/local/lib/python3.10/dist-packages (1.13.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.13.3) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai==1.13.3) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.13.3) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.13.3) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai==1.13.3) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai==1.13.3) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai==1.13.3) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.13.3) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.13.3) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.13.3) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.13.3) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.13.3) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.13.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.13.3) (2.18.2)

# %%
# Add Azure OpenAI package
from openai import AzureOpenAI
import requests

# %%
#Set the API Keys, Endpoint and Model Deployment
azure_oai_endpoint ="https://adpshared21-30.openai.azure.com/"
azure_oai_key ="c4bcfc2a6c8e490c9ed64445be0e3cfe"
azure_oai_deployment ="dall-e-3"

# %%
# Initialize the Azure OpenAI client
azure_endpoint = azure_oai_endpoint
api_key=azure_oai_key
api_version="2024-02-15-preview"

# %%
# Get prompt for image to be generated
prompt = input("\nEnter a prompt to request an image: ")
# Out:
# Enter a prompt to request an image: a dog flying in the sky

# %%
# Call the DALL-E model
url = "{}openai/deployments/dalle3/images/generations?api-version={}".format(azure_endpoint, api_version)
headers= { "api-key": api_key, "Content-Type": "application/json" }
body = {
            "prompt": prompt,
            "n": 1,
            "size": "1024x1024"
        }

# %%
 response = requests.post(url, headers=headers, json=body)
 print(response.text)
# Out:
# {"created":1715671601,"data":[{"content_filter_results":{"hate":{"filtered":false,"severity":"safe"},"self_harm":{"filtered":false,"severity":"safe"},"sexual":{"filtered":false,"severity":"safe"},"violence":{"filtered":false,"severity":"safe"}},"prompt_filter_results":{"hate":{"filtered":false,"severity":"safe"},"profanity":{"detected":false,"filtered":false},"self_harm":{"filtered":false,"severity":"safe"},"sexual":{"filtered":false,"severity":"safe"},"violence":{"filtered":false,"severity":"safe"}},"revised_prompt":"A brown dog with a friendly face and wagging tail, soaring high in a blue sky filled with fluffy white clouds. The dog appears carefree, its ears are flapping in the wind as it navigates through the sky, carrying a frisbee in its mouth. Rays of sunlight are breaking through the clouds, casting a warm glow on the leaping dog. Below, the landscape is a beautiful combination of a tranquil lake, vibrant green fields and some colorful wildflowers.","url":"https://dalleprodaue.blob.core.windows.net/private/images/698c7674-1db4-4865-9597-0f5187a63d04/generated_00.png?se=2024-05-15T07%3A26%3A57Z&sig=0J6YH8MD56DdkPELt4PpykmMngQuPODGF0s1b8sZTgA%3D&ske=2024-05-18T13%3A24%3A33Z&skoid=f4f58869-78fa-4857-8a87-4ce5ae4ba8c3&sks=b&skt=2024-05-11T13%3A24%3A33Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02"}]}

# %%
 # Get the revised prompt and image URL from the response
 revised_prompt = response.json()['data'][0]['revised_prompt']
 image_url = response.json()['data'][0]['url']

 # Display the URL for the generated image
 print(revised_prompt)
 print(image_url)
# Out:
# A brown and black spotted dog with long, floppy ears and a wagging tail, is soaring joyfully through the sky. It is surrounded by fluffy white clouds, and the vibrant blue sky offers a contrasting backdrop. The sun lighting up the scene from a corner casts a warm glow on the dog's fur, adding depth to the scene. The dog's paws are stretched out as it navigates around the wind currents, its eyes sparkling with excitement.
# https://dalleprodaue.blob.core.windows.net/private/images/4b9a59b4-4d41-4452-b58f-ce3c197946e2/generated_00.png?se=2024-05-15T07%3A21%3A48Z&sig=4BECDhQ8GpayGGKq%2Fsw%2FAirN0EHLTfb0Yl%2BrR3kMd4k%3D&ske=2024-05-18T16%3A35%3A04Z&skoid=f4f58869-78fa-4857-8a87-4ce5ae4ba8c3&sks=b&skt=2024-05-11T16%3A35%3A04Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02

# %%
save_path = 'image_name.jpg'

# Download the image and save it to the specified path
response = requests.get(image_url)
if response.status_code == 200:
    with open(save_path, 'wb') as f:
        f.write(response.content)
    print(f"Image saved to {save_path}")
else:
    print("Failed to download the image")
# Out:
# Image saved to image_name.jpg
